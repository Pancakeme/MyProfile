# %%
import torch
import numpy as np


from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

import torch.backends.cudnn as cudnn
import torch.nn as nn
import torch.nn.functional as F

import torch.optim as optim

num_workers = 0

batch_size = 20

valid_size = 0.2

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

train_data = datasets.CIFAR10('data', train=True,
                              download=True, transform=transform_train)
test_data = datasets.CIFAR10('data', train=False,
                             download=True, transform=transform_test)

num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, 
    num_workers=num_workers)

classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']

class BasicBlock(nn.Module):
  expansion = 1
  def __init__(self, in_planes, planes, stride=1):
    super(BasicBlock, self).__init__()
    self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )
  
  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.bn2(self.conv2(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class BottleNeck(nn.Module):
  expansion = 4

  def __init__(self, in_planes, planes, stride=1):
    super(BottleNeck, self).__init__()
    self.conv1 = nn.Conv2d(in_planes , planes, kernel_size=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)
    self.conv3 = nn.Conv2d(planes, self.expansion*planes, kernel_size=1, bias=False)
    self.bn3 = nn.BatchNorm2d(self.expansion*planes)

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes :
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = F.relu(self.bn2(self.conv2(out)))
    out = self.bn3(self.conv3(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class ResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(ResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
    self.linear = nn.Linear(512*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
      layers.append(block(self.in_planes, planes, stride))
      self.in_planes = planes * block.expansion      
    return nn.Sequential(*layers)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

ResNet18 = ResNet(BasicBlock, [2,2,2,2])

print(ResNet18)

if torch.cuda.is_available() == True:
  ResNet18 = torch.nn.DataParallel(ResNet18)
  cudnn.benchmark = True

criterion = nn.CrossEntropyLoss()

optimizer = optim.SGD(ResNet18.parameters(), lr=0.01, momentum=0.9, weight_decay=0.0001)

n_epochs = 200

valid_loss_min = np.Inf

for epochs in range(1, n_epochs + 1):
  train_loss=0.1
  valid_loss=0.1

  ResNet18.train()

  for batch_idx, (data, target) in enumerate(train_loader):
    """if train_on_gpu:
      data, target = data.cuda(), target.cuda()"""
    
    if torch.cuda.is_available() == True:
      data, target=data.cuda(),target.cuda()

    optimizer.zero_grad()
    output = ResNet18(data)
    loss = criterion(output, target)
    loss.backward()
    optimizer.step()
    train_loss+=loss.item()*data.size(0)

  ResNet18.eval()

  for batch_idx, (data, target) in enumerate(train_loader):
    """if train_on_gpu:
      data, target = data.cuda(), target.cuda()"""

    if torch.cuda.is_available() == True:
      data, target=data.cuda(),target.cuda()

    output = ResNet18(data)
    loss = criterion(output, target)
    valid_loss += loss.item()*data.size(0)

  train_loss = train_loss/len(train_loader.sampler)
  valid_loss = valid_loss/len(valid_loader.sampler)

  print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
      epochs, train_loss, valid_loss))


test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

ResNet18.eval()

for batch_idx, (data, target) in enumerate(test_loader):
  """if train_on_gpu:
    data, target = data.cuda(), target.cuda()"""
  
  if torch.cuda.is_available() == True:
      data, target=data.cuda(),target.cuda()

  output = ResNet18(data)
  loss = criterion(output, target)
  test_loss += loss.item()*data.size(0)
  _, pred = torch.max(output, 1)   
  correct_tensor = pred.eq(target.data.view_as(pred))
  correct = np.squeeze(correct_tensor.numpy()) if not torch.cuda.is_available() else np.squeeze(correct_tensor.cpu().numpy())
  for i in range(batch_size):
    label = target.data[i]
    class_correct[label] += correct[i].item()
    class_total[label] += 1

test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
  if class_total[i] > 0:
    print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
        classes[i], 100 * class_correct[i] / class_total[i],
        np.sum(class_correct[i]), np.sum(class_total[i])))
  else:
    print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting data/cifar-10-python.tar.gz to data
# Files already downloaded and verified
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=512, out_features=10, bias=True)
# )
# Epoch: 1 	Training Loss: 1.629259 	Validation Loss: 5.292350
# Epoch: 2 	Training Loss: 1.119250 	Validation Loss: 3.603005
# Epoch: 3 	Training Loss: 0.881409 	Validation Loss: 2.729462
# Epoch: 4 	Training Loss: 0.732424 	Validation Loss: 2.464714
# Epoch: 5 	Training Loss: 0.637448 	Validation Loss: 2.613733
# Epoch: 6 	Training Loss: 0.572063 	Validation Loss: 2.318886
# Epoch: 7 	Training Loss: 0.513790 	Validation Loss: 1.798850
# Epoch: 8 	Training Loss: 0.463713 	Validation Loss: 1.727985
# Epoch: 9 	Training Loss: 0.433809 	Validation Loss: 1.496262
# Epoch: 10 	Training Loss: 0.399091 	Validation Loss: 1.343925
# Epoch: 11 	Training Loss: 0.372680 	Validation Loss: 1.284043
# Epoch: 12 	Training Loss: 0.348434 	Validation Loss: 1.169560
# Epoch: 13 	Training Loss: 0.328796 	Validation Loss: 1.109521
# Epoch: 14 	Training Loss: 0.306545 	Validation Loss: 0.995191
# Epoch: 15 	Training Loss: 0.287120 	Validation Loss: 0.911652
# Epoch: 16 	Training Loss: 0.271711 	Validation Loss: 0.881255
# Epoch: 17 	Training Loss: 0.255918 	Validation Loss: 0.930097
# Epoch: 18 	Training Loss: 0.246218 	Validation Loss: 0.842891
# Epoch: 19 	Training Loss: 0.234967 	Validation Loss: 0.693972
# Epoch: 20 	Training Loss: 0.220263 	Validation Loss: 0.719830
# Epoch: 21 	Training Loss: 0.212048 	Validation Loss: 0.751358
# Epoch: 22 	Training Loss: 0.202400 	Validation Loss: 0.612388
# Epoch: 23 	Training Loss: 0.194790 	Validation Loss: 0.614019
# Epoch: 24 	Training Loss: 0.181002 	Validation Loss: 0.546189
# Epoch: 25 	Training Loss: 0.172532 	Validation Loss: 0.552121
# Epoch: 26 	Training Loss: 0.169437 	Validation Loss: 0.457998
# Epoch: 27 	Training Loss: 0.159761 	Validation Loss: 0.548735
# Epoch: 28 	Training Loss: 0.151034 	Validation Loss: 0.446140
# Epoch: 29 	Training Loss: 0.148611 	Validation Loss: 0.424269
# Epoch: 30 	Training Loss: 0.142960 	Validation Loss: 0.509181
# Epoch: 31 	Training Loss: 0.135852 	Validation Loss: 0.441454
# Epoch: 32 	Training Loss: 0.131286 	Validation Loss: 0.388262
# Epoch: 33 	Training Loss: 0.129943 	Validation Loss: 0.379254
# Epoch: 34 	Training Loss: 0.127241 	Validation Loss: 0.426697
# Epoch: 35 	Training Loss: 0.125062 	Validation Loss: 0.329579
# Epoch: 36 	Training Loss: 0.116831 	Validation Loss: 0.428209
# Epoch: 37 	Training Loss: 0.109971 	Validation Loss: 0.392527
# Epoch: 38 	Training Loss: 0.110541 	Validation Loss: 0.351314
# Epoch: 39 	Training Loss: 0.103702 	Validation Loss: 0.341561
# Epoch: 40 	Training Loss: 0.106202 	Validation Loss: 0.260726
# Epoch: 41 	Training Loss: 0.103247 	Validation Loss: 0.279110
# Epoch: 42 	Training Loss: 0.100586 	Validation Loss: 0.298347
# Epoch: 43 	Training Loss: 0.100768 	Validation Loss: 0.301102
# Epoch: 44 	Training Loss: 0.096684 	Validation Loss: 0.319817
# Epoch: 45 	Training Loss: 0.097776 	Validation Loss: 0.276930
# Epoch: 46 	Training Loss: 0.091878 	Validation Loss: 0.274300
# Epoch: 47 	Training Loss: 0.093892 	Validation Loss: 0.385552
# Epoch: 48 	Training Loss: 0.092944 	Validation Loss: 0.292926
# Epoch: 49 	Training Loss: 0.089746 	Validation Loss: 0.229229
# Epoch: 50 	Training Loss: 0.085677 	Validation Loss: 0.240357
# Epoch: 51 	Training Loss: 0.086235 	Validation Loss: 0.218560
# Epoch: 52 	Training Loss: 0.089092 	Validation Loss: 0.292841
# Epoch: 53 	Training Loss: 0.079584 	Validation Loss: 0.323395
# Epoch: 54 	Training Loss: 0.086173 	Validation Loss: 0.214311
# Epoch: 55 	Training Loss: 0.080795 	Validation Loss: 0.207489
# Epoch: 56 	Training Loss: 0.080326 	Validation Loss: 0.281040
# Epoch: 57 	Training Loss: 0.078416 	Validation Loss: 0.235015
# Epoch: 58 	Training Loss: 0.078643 	Validation Loss: 0.259001
# Epoch: 59 	Training Loss: 0.075998 	Validation Loss: 0.250351
# Epoch: 60 	Training Loss: 0.080196 	Validation Loss: 0.187704
# Epoch: 61 	Training Loss: 0.073063 	Validation Loss: 0.171985
# Epoch: 62 	Training Loss: 0.076810 	Validation Loss: 0.277040
# Epoch: 63 	Training Loss: 0.081821 	Validation Loss: 0.241592
# Epoch: 64 	Training Loss: 0.076001 	Validation Loss: 0.223923
# Epoch: 65 	Training Loss: 0.072101 	Validation Loss: 0.305834
# Epoch: 66 	Training Loss: 0.076177 	Validation Loss: 0.199010
# Epoch: 67 	Training Loss: 0.072084 	Validation Loss: 0.197273
# Epoch: 68 	Training Loss: 0.076209 	Validation Loss: 0.238704
# Epoch: 69 	Training Loss: 0.075107 	Validation Loss: 0.255906
# Epoch: 70 	Training Loss: 0.071007 	Validation Loss: 0.209719
# Epoch: 71 	Training Loss: 0.073476 	Validation Loss: 0.204728
# Epoch: 72 	Training Loss: 0.071335 	Validation Loss: 0.241248
# Epoch: 73 	Training Loss: 0.069830 	Validation Loss: 0.280199
# Epoch: 74 	Training Loss: 0.071098 	Validation Loss: 0.255254
# Epoch: 75 	Training Loss: 0.070355 	Validation Loss: 0.246403
# Epoch: 76 	Training Loss: 0.071455 	Validation Loss: 0.200515
# Epoch: 77 	Training Loss: 0.066592 	Validation Loss: 0.190672
# Epoch: 78 	Training Loss: 0.067962 	Validation Loss: 0.166473
# Epoch: 79 	Training Loss: 0.067264 	Validation Loss: 0.233722
# Epoch: 80 	Training Loss: 0.067074 	Validation Loss: 0.162236
# Epoch: 81 	Training Loss: 0.064299 	Validation Loss: 0.202285
# Epoch: 82 	Training Loss: 0.068166 	Validation Loss: 0.142789
# Epoch: 83 	Training Loss: 0.071780 	Validation Loss: 0.232504
# Epoch: 84 	Training Loss: 0.070431 	Validation Loss: 0.236183
# Epoch: 85 	Training Loss: 0.065952 	Validation Loss: 0.198101
# Epoch: 86 	Training Loss: 0.065764 	Validation Loss: 0.225637
# Epoch: 87 	Training Loss: 0.071205 	Validation Loss: 0.189800
# Epoch: 88 	Training Loss: 0.070575 	Validation Loss: 0.193175
# Epoch: 89 	Training Loss: 0.064916 	Validation Loss: 0.209524
# Epoch: 90 	Training Loss: 0.065728 	Validation Loss: 0.219876
# Epoch: 91 	Training Loss: 0.066661 	Validation Loss: 0.199867
# Epoch: 92 	Training Loss: 0.068378 	Validation Loss: 0.185925
# Epoch: 93 	Training Loss: 0.066451 	Validation Loss: 0.232627
# Epoch: 94 	Training Loss: 0.064327 	Validation Loss: 0.183954
# Epoch: 95 	Training Loss: 0.068398 	Validation Loss: 0.249650
# Epoch: 96 	Training Loss: 0.066755 	Validation Loss: 0.172561
# Epoch: 97 	Training Loss: 0.061223 	Validation Loss: 0.158623
# Epoch: 98 	Training Loss: 0.061471 	Validation Loss: 0.143286
# Epoch: 99 	Training Loss: 0.062487 	Validation Loss: 0.184005
# Epoch: 100 	Training Loss: 0.066793 	Validation Loss: 0.255227
# Epoch: 101 	Training Loss: 0.062301 	Validation Loss: 0.236789
# Epoch: 102 	Training Loss: 0.064463 	Validation Loss: 0.167125
# Epoch: 103 	Training Loss: 0.068459 	Validation Loss: 0.134953
# Epoch: 104 	Training Loss: 0.060923 	Validation Loss: 0.252060
# Epoch: 105 	Training Loss: 0.063181 	Validation Loss: 0.138407
# Epoch: 106 	Training Loss: 0.063721 	Validation Loss: 0.140584
# Epoch: 107 	Training Loss: 0.066090 	Validation Loss: 0.233216
# Epoch: 108 	Training Loss: 0.065387 	Validation Loss: 0.178323
# Epoch: 109 	Training Loss: 0.062704 	Validation Loss: 0.175109
# Epoch: 110 	Training Loss: 0.064768 	Validation Loss: 0.210164
# Epoch: 111 	Training Loss: 0.062955 	Validation Loss: 0.185060
# Epoch: 112 	Training Loss: 0.065538 	Validation Loss: 0.163513
# Epoch: 113 	Training Loss: 0.065115 	Validation Loss: 0.227363
# Epoch: 114 	Training Loss: 0.064870 	Validation Loss: 0.147997
# Epoch: 115 	Training Loss: 0.056137 	Validation Loss: 0.232179
# Epoch: 116 	Training Loss: 0.061971 	Validation Loss: 0.186626
# Epoch: 117 	Training Loss: 0.067975 	Validation Loss: 0.167820
# Epoch: 118 	Training Loss: 0.060695 	Validation Loss: 0.128958
# Epoch: 119 	Training Loss: 0.059188 	Validation Loss: 0.224674
# Epoch: 120 	Training Loss: 0.058388 	Validation Loss: 0.176278
# Epoch: 121 	Training Loss: 0.059172 	Validation Loss: 0.251889
# Epoch: 122 	Training Loss: 0.060315 	Validation Loss: 0.157744
# Epoch: 123 	Training Loss: 0.066251 	Validation Loss: 0.186070
# Epoch: 124 	Training Loss: 0.059701 	Validation Loss: 0.157693
# Epoch: 125 	Training Loss: 0.064576 	Validation Loss: 0.245370
# Epoch: 126 	Training Loss: 0.059552 	Validation Loss: 0.122577
# Epoch: 127 	Training Loss: 0.058978 	Validation Loss: 0.194536
# Epoch: 128 	Training Loss: 0.062339 	Validation Loss: 0.224063
# Epoch: 129 	Training Loss: 0.065449 	Validation Loss: 0.172137
# Epoch: 130 	Training Loss: 0.061656 	Validation Loss: 0.176564
# Epoch: 131 	Training Loss: 0.055883 	Validation Loss: 0.166281
# Epoch: 132 	Training Loss: 0.062012 	Validation Loss: 0.192464
# Epoch: 133 	Training Loss: 0.063606 	Validation Loss: 0.184691
# Epoch: 134 	Training Loss: 0.061442 	Validation Loss: 0.196885
# Epoch: 135 	Training Loss: 0.059600 	Validation Loss: 0.166683
# Epoch: 136 	Training Loss: 0.056098 	Validation Loss: 0.202359
# Epoch: 137 	Training Loss: 0.057433 	Validation Loss: 0.223363
# Epoch: 138 	Training Loss: 0.063727 	Validation Loss: 0.195003
# Epoch: 139 	Training Loss: 0.065427 	Validation Loss: 0.165778
# Epoch: 140 	Training Loss: 0.060780 	Validation Loss: 0.179727
# Epoch: 141 	Training Loss: 0.057908 	Validation Loss: 0.203506
# Epoch: 142 	Training Loss: 0.056747 	Validation Loss: 0.164117
# Epoch: 143 	Training Loss: 0.062730 	Validation Loss: 0.272027
# Epoch: 144 	Training Loss: 0.061072 	Validation Loss: 0.190963
# Epoch: 145 	Training Loss: 0.058968 	Validation Loss: 0.175322
# Epoch: 146 	Training Loss: 0.056627 	Validation Loss: 0.180981
# Epoch: 147 	Training Loss: 0.059576 	Validation Loss: 0.168404
# Epoch: 148 	Training Loss: 0.056895 	Validation Loss: 0.298774
# Epoch: 149 	Training Loss: 0.060177 	Validation Loss: 0.163657
# Epoch: 150 	Training Loss: 0.056610 	Validation Loss: 0.219056
# Epoch: 151 	Training Loss: 0.061832 	Validation Loss: 0.164210
# Epoch: 152 	Training Loss: 0.054677 	Validation Loss: 0.174197
# Epoch: 153 	Training Loss: 0.063834 	Validation Loss: 0.140060
# Epoch: 154 	Training Loss: 0.055465 	Validation Loss: 0.145018
# Epoch: 155 	Training Loss: 0.054807 	Validation Loss: 0.223149
# Epoch: 156 	Training Loss: 0.061166 	Validation Loss: 0.242891
# Epoch: 157 	Training Loss: 0.055907 	Validation Loss: 0.198963
# Epoch: 158 	Training Loss: 0.060041 	Validation Loss: 0.141388
# Epoch: 159 	Training Loss: 0.056181 	Validation Loss: 0.181419
# Epoch: 160 	Training Loss: 0.057583 	Validation Loss: 0.162117
# Epoch: 161 	Training Loss: 0.054937 	Validation Loss: 0.212275
# Epoch: 162 	Training Loss: 0.058121 	Validation Loss: 0.191659
# Epoch: 163 	Training Loss: 0.059908 	Validation Loss: 0.146845
# Epoch: 164 	Training Loss: 0.060937 	Validation Loss: 0.136657
# Epoch: 165 	Training Loss: 0.057916 	Validation Loss: 0.164892
# Epoch: 166 	Training Loss: 0.053117 	Validation Loss: 0.124683
# Epoch: 167 	Training Loss: 0.062399 	Validation Loss: 0.291147
# Epoch: 168 	Training Loss: 0.054326 	Validation Loss: 0.203687
# Epoch: 169 	Training Loss: 0.061664 	Validation Loss: 0.166955
# Epoch: 170 	Training Loss: 0.054673 	Validation Loss: 0.190278
# Epoch: 171 	Training Loss: 0.052512 	Validation Loss: 0.207997
# Epoch: 172 	Training Loss: 0.052731 	Validation Loss: 0.139806
# Epoch: 173 	Training Loss: 0.062939 	Validation Loss: 0.153414
# Epoch: 174 	Training Loss: 0.057344 	Validation Loss: 0.190809
# Epoch: 175 	Training Loss: 0.055588 	Validation Loss: 0.184634
# Epoch: 176 	Training Loss: 0.061531 	Validation Loss: 0.197999
# Epoch: 177 	Training Loss: 0.056909 	Validation Loss: 0.266845
# Epoch: 178 	Training Loss: 0.060494 	Validation Loss: 0.181478
# Epoch: 179 	Training Loss: 0.056292 	Validation Loss: 0.155314
# Epoch: 180 	Training Loss: 0.060155 	Validation Loss: 0.201038
# Epoch: 181 	Training Loss: 0.057701 	Validation Loss: 0.145174
# Epoch: 182 	Training Loss: 0.063324 	Validation Loss: 0.247420
# Epoch: 183 	Training Loss: 0.060568 	Validation Loss: 0.169847
# Epoch: 184 	Training Loss: 0.054690 	Validation Loss: 0.185630
# Epoch: 185 	Training Loss: 0.057058 	Validation Loss: 0.148162
# Epoch: 186 	Training Loss: 0.055012 	Validation Loss: 0.220706
# Epoch: 187 	Training Loss: 0.055072 	Validation Loss: 0.152228
